# %% [markdown]
# ## Part 3: Building the model
#
# This is our third and final part of this project. It will be divided into different sections.
#
# 1. Section 1: Data Preprocessing.
# 2. Section 2: Support Vector Regression.
# 3. Section 3: Random Forest.
# 4. Section 4: Lasso Regression.
# 5. Section 5: Logistic Regression.
# 6. Section 6: Model Evaluation.

# %%
import pandas as pd
import numpy as np
import plotly.express as px
from plotly.offline import plot, iplot, init_notebook_mode
import plotly.graph_objs as go
init_notebook_mode(connected=True)
pd.set_option('display.max_columns', None)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv(r'model_data.csv',index_col=[0])

# %%
df
# Out:
#                        country age_group                         purpose  \
# 0                   SWIZERLAND     45-64            Leisure and Holidays
# 1               UNITED KINGDOM     25-44            Leisure and Holidays
# 2               UNITED KINGDOM     25-44  Visiting Friends and Relatives
# 3               UNITED KINGDOM     25-44            Leisure and Holidays
# 4                        CHINA      1-24            Leisure and Holidays
# ...                        ...       ...                             ...
# 4804                       UAE     45-64                        Business
# 4805  UNITED STATES OF AMERICA     25-44            Leisure and Holidays
# 4806               NETHERLANDS      1-24            Leisure and Holidays
# 4807              SOUTH AFRICA     25-44                        Business
# 4808            UNITED KINGDOM     25-44            Leisure and Holidays
#
#          main_activity                   info_source tour_arrangement  \
# ...
